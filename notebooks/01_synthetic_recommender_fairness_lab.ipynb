# %% [markdown]
# # Synthetic Recommender Fairness Lab
#
# Run the script first to generate outputs:
#
# ```bash
# python scripts/run_synthetic_recommender_lab.py
# ```
#
# Then load the generated CSV files for exploratory analysis.

# %%
import pandas as pd
from pathlib import Path

base = Path('../outputs/results')
comparison = pd.read_csv(base / 'synthetic_algorithm_comparison.csv')
fairness = pd.read_csv(base / 'synthetic_exposure_fairness_audit.csv')
bubbles = pd.read_csv(base / 'synthetic_filter_bubble_report.csv')
trust = pd.read_csv(base / 'synthetic_user_trust_audit.csv')
comparison.head()

# %%
fairness.sort_values(['method', 'absolute_exposure_gap'], ascending=[True, False]).head(20)
